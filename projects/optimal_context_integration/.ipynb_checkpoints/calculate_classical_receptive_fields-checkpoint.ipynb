# %% [markdown]
# # Calculate the classical receptive fields based on 500 images and 18 filters
#
# ## Get all the images and convert them into gray images

# %%
import os
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
# %matplotlib inline



drive_path = '/Users/zhixinlu/GitHub/swdb_2017_tools/projects/optimal_context_integration/'
mypath = os.path.join(drive_path,'images/')
image_file_names = [f for f in os.listdir(mypath) if os.path.isfile(os.path.join(mypath, f))]
_ = image_file_names.pop(0)

# %%
images = [(np.mean(plt.imread(image_file_name),2)) for image_file_name in image_file_names]

# %%
images_size = [(np.shape(plt.imread(image_file_name))) for image_file_name in image_file_names]

# %%
df_image = pd.DataFrame(images)
df_image.keys()
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
np.shape(image_0)
# Out:
# (321, 481, 3)

# %%
for image in images[0:1]:
    plt.imshow(image)

# %%
plt.imshow((np.mean(image_0,2)))

# %%
filter
